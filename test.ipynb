# %% [markdown]
# # step 1: Install Required Libraries

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.60.1-cp313-cp313-win_amd64.whl.metadata (114 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.1 MB 10.5 MB/s eta 0:00:01
#    ------------ --------------------------- 2.6/8.1 MB 6.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.4/8.1 MB 6.2 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.1 MB 5.1 MB/s eta 0:00:01
#    --------------------- ------------------ 4.5/8.1 MB 4.5 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import mysql.connector
import time

# %% [markdown]
# # step 2 : Read the CSV Files

# %%
customers = pd.read_csv("olist_customers_dataset.csv")
customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
geolocation = pd.read_csv("olist_geolocation_dataset.csv")
geolocation
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
order_items = pd.read_csv("olist_order_items_dataset.csv")
order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
order_payments = pd.read_csv("olist_order_payments_dataset.csv")
order_payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
order_reviews = pd.read_csv("olist_order_reviews_dataset.csv")
order_reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
orders = pd.read_csv("olist_orders_dataset.csv")
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
products = pd.read_csv("olist_products_dataset.csv")
products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
sellers = pd.read_csv("olist_sellers_dataset.csv")
sellers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
product_category = pd.read_csv("product_category_name_translation.csv")
product_category
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %% [markdown]
# # step 3: Merge the CSV Files

# %%
products = pd.merge(products, product_category, on='product_category_name', how='left')
products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
merge_df = orders.merge(order_items, on='order_id', how='left')
merge_df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 113420  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 113421  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 113422  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113423  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113424  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
merge_df = merge_df.merge(order_payments, on='order_id', how='left')
merge_df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 118429  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 118430  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 118431  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118432  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118433  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
merge_df = merge_df.merge(customers, on='customer_id', how='left')
merge_df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 118429  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 118430  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 118431  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118432  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118433  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
merge_df = merge_df.merge(products, on='product_id', how='left')
merge_df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 118429  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 118430  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 118431  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118432  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118433  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
merge_df = merge_df.merge(sellers, on='seller_id', how='left')
merge_df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 118429  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 118430  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 118431  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118432  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118433  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
merge_df = merge_df.merge(product_category, on='product_category_name', how='left')
merge_df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 118429  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 118430  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 118431  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118432  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118433  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
# Step 4: Remove duplicates
merge_df.drop_duplicates(inplace=True)

# %%
# Step 5: Handle missing values
datetime_cols = [
    'order_purchase_timestamp', 'order_approved_at',
    'order_delivered_carrier_date', 'order_delivered_customer_date',
    'order_estimated_delivery_date', 'shipping_limit_date'
]

num_cols = [
    'price', 'freight_value', 'payment_installments',
    'payment_value', 'payment_sequential', 'review_score'
]

# Convert datetime columns safely
for col in datetime_cols:
    merge_df[col] = pd.to_datetime(merge_df[col], errors='coerce')

# %%
    # Step 6: Merge order_items with orders, customers, payments, reviews, sellers
merged_df = (
    order_items
    .merge(orders, on='order_id', how='left')
    .merge(customers, on='customer_id', how='left')
    .merge(order_payments, on='order_id', how='left')
    .merge(order_reviews, on='order_id', how='left')
    .merge(sellers, on='seller_id', how='left')
    .merge(products, on='product_id', how='left'))

# %%
# Step 7: Remove duplicates and handle missing values
merged_df.drop_duplicates(inplace=True)
merged_df.fillna({
    'order_status': 'Unknown',
    'payment_type': 'Unknown',
    'customer_city': 'Unknown',
    'customer_state': 'Unknown',
    'seller_city': 'Unknown',
    'seller_state': 'Unknown',
    'product_category_name': 'Unknown'
}, inplace=True)

# %%
# Step 8: Remove duplicates and handle missing values
merged_df.drop_duplicates(inplace=True)
merged_df.fillna({
    'order_status': 'Unknown',
    'payment_type': 'Unknown',
    'customer_city': 'Unknown',
    'customer_state': 'Unknown',
    'seller_city': 'Unknown',
    'seller_state': 'Unknown',
    'product_category_name': 'Unknown'
}, inplace=True)
insert_df = merged_df[[
    'order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
    'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date',
    'order_estimated_delivery_date', 'order_item_id', 'product_id', 'seller_id',
    'shipping_limit_date', 'price', 'freight_value', 'payment_sequential', 'payment_type',
    'payment_installments', 'payment_value', 'review_score', 'customer_city',
    'customer_state', 'product_category_name', 'seller_city', 'seller_state'
]]

# %%
# Step 9: Clean and convert data types and remove NaN properly
insert_df['order_purchase_timestamp'] = pd.to_datetime(insert_df['order_purchase_timestamp'], errors='coerce')
insert_df['order_approved_at'] = pd.to_datetime(insert_df['order_approved_at'], errors='coerce')
insert_df['order_delivered_carrier_date'] = pd.to_datetime(insert_df['order_delivered_carrier_date'], errors='coerce')
insert_df['order_delivered_customer_date'] = pd.to_datetime(insert_df['order_delivered_customer_date'], errors='coerce')
insert_df['order_estimated_delivery_date'] = pd.to_datetime(insert_df['order_estimated_delivery_date'], errors='coerce')
insert_df['shipping_limit_date'] = pd.to_datetime(insert_df['shipping_limit_date'], errors='coerce')

# Replace numeric NaN with 0
num_cols = ['price', 'freight_value', 'payment_installments', 'payment_value', 'review_score']
insert_df[num_cols] = insert_df[num_cols].fillna(0)

# Replace all remaining NaN or None with 'Unknown' (for text columns)
insert_df = insert_df.fillna('Unknown')

# Finally, replace possible 'nan' strings with 'Unknown'
insert_df = insert_df.replace('nan', 'Unknown')
insert_df = insert_df.replace('NaN', 'Unknown')

# Fill missing values in text columns
text_cols = [col for col in merge_df.columns if col not in datetime_cols + num_cols]
merge_df[text_cols] = merge_df[text_cols].fillna('Unknown')

# Convert datetime to string for SQL insertion
for col in datetime_cols:
    merge_df[col] = merge_df[col].apply(lambda x: x.strftime('%Y-%m-%d %H:%M:%S') if pd.notnull(x) else None)
# Out:
# C:\Users\Kaviya Kumar\AppData\Local\Temp\ipykernel_8484\2912487667.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insert_df['order_purchase_timestamp'] = pd.to_datetime(insert_df['order_purchase_timestamp'], errors='coerce')
# C:\Users\Kaviya Kumar\AppData\Local\Temp\ipykernel_8484\2912487667.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insert_df['order_approved_at'] = pd.to_datetime(insert_df['order_approved_at'], errors='coerce')
# ...

# %%
# Step 10: Clean your dataframe properly
datetime_cols = [
    'order_purchase_timestamp', 'order_approved_at',
    'order_delivered_carrier_date', 'order_delivered_customer_date',
    'order_estimated_delivery_date', 'shipping_limit_date'
]

num_cols = [
    'price', 'freight_value', 'payment_installments',
    'payment_value', 'payment_sequential', 'review_score'
]

# %%
# Convert datetime columns safely
for col in datetime_cols:
    insert_df[col] = pd.to_datetime(insert_df[col], errors='coerce')

# %%
# Convert numeric columns safely (any non-numeric value -> 0)
for col in num_cols:
    insert_df[col] = pd.to_numeric(insert_df[col], errors='coerce').fillna(0).astype(int)

# %%
# Replace missing values in text columns only
text_cols = [col for col in insert_df.columns if col not in datetime_cols + num_cols]
insert_df[text_cols] = insert_df[text_cols].fillna('Unknown')
print("Data cleaned successfully.")
# Out:
# Data cleaned successfully.

# %%
# Step 11: Convert datetime to strings for SQL
for col in datetime_cols:
    insert_df[col] = insert_df[col].apply(lambda x: x.strftime('%Y-%m-%d %H:%M:%S') if pd.notnull(x) else None)

# %%
# Step 12: Convert to tuples for insertion
records = [tuple(row) for row in insert_df.to_numpy()]
print("Columns in DataFrame:", len(insert_df.columns))
print("Columns in first record:", len(records[0]))
print("Total records to insert:", len(records))
# Out:
# Columns in DataFrame: 24
# Columns in first record: 24
# Total records to insert: 118310

# %%
# Step 13: Convert DataFrame to tuples
records = [tuple(row) for row in merge_df.to_numpy()]
print("Columns in DataFrame:", len(merge_df.columns))
print("Columns in first record:", len(records[0]))
print("Total records to insert:", len(records))
# Step 6: Remove duplicates and handle missing values
merged_df.drop_duplicates(inplace=True)
merged_df.fillna({
    'order_status': 'Unknown',
    'payment_type': 'Unknown',
    'customer_city': 'Unknown',
    'customer_state': 'Unknown',
    'seller_city': 'Unknown',
    'seller_state': 'Unknown',
    'product_category_name': 'Unknown'
}, inplace=True)
# Out:
# Columns in DataFrame: 36
# Columns in first record: 36
# Total records to insert: 118434

# %%
# Step 14: Connect to MySQL
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="21Kaviya#2003",  # replace with your MySQL password
    database="ecommerce"       # make sure this database exists
)
cursor = mydb.cursor()

# %%
# Step 15: Create table in SQL (run only once)
create_table_query = """
CREATE TABLE IF NOT EXISTS table_sales (
    order_id VARCHAR(50),
    customer_id VARCHAR(50),
    order_status VARCHAR(50),
    order_purchase_timestamp DATETIME,
    order_approved_at DATETIME,
    order_delivered_carrier_date DATETIME,
    order_delivered_customer_date DATETIME,
    order_estimated_delivery_date DATETIME,
    order_item_id INT,
    product_id VARCHAR(50),
    seller_id VARCHAR(50),
    shipping_limit_date DATETIME,
    price FLOAT,
    freight_value FLOAT,
    payment_sequential INT,
    payment_type VARCHAR(50),
    payment_installments INT,
    payment_value FLOAT,
    review_score INT,
    customer_city VARCHAR(100),
    customer_state VARCHAR(50),
    product_category_name VARCHAR(100),
    seller_city VARCHAR(100),
    seller_state VARCHAR(50)
)
"""
cursor.execute(create_table_query)
mydb.commit()

# %%
# Step 16: Insert into MySQL in batches
insert_query = """
INSERT INTO table_sales (
    order_id, customer_id, order_status, order_purchase_timestamp,
    order_approved_at, order_delivered_carrier_date, order_delivered_customer_date,
    order_estimated_delivery_date, order_item_id, product_id, seller_id,
    shipping_limit_date, price, freight_value, payment_sequential, payment_type,
    payment_installments, payment_value, review_score, customer_city,
    customer_state, product_category_name, seller_city, seller_state
) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

batch_size = 500
for i in range(0, len(records), batch_size):
    batch = records[i:i+batch_size]
    cursor.executemany(insert_query, batch)
    mydb.commit()
    print(f"Inserted batch {i//batch_size + 1}")
    time.sleep(1)  # optional small pause

print("All records inserted successfully.")

# Step 9: Verify total records inserted
cursor.execute("SELECT COUNT(*) FROM table_sales;")
total = cursor.fetchone()[0]
print("Total records in MySQL table:", total)
# Out:
# Inserted batch 1
# Inserted batch 2
# Inserted batch 3
# Inserted batch 4
# Inserted batch 5
# Inserted batch 6
# Inserted batch 7
# Inserted batch 8
# Inserted batch 9
# Inserted batch 10
# Inserted batch 11
# Inserted batch 12
# Inserted batch 13
# Inserted batch 14
# Inserted batch 15
# Inserted batch 16
# Inserted batch 17
# Inserted batch 18
# Inserted batch 19
# Inserted batch 20
# Inserted batch 21
# Inserted batch 22
# Inserted batch 23
# Inserted batch 24
# Inserted batch 25
# Inserted batch 26
# Inserted batch 27
# Inserted batch 28
# Inserted batch 29
# Inserted batch 30
# Inserted batch 31
# Inserted batch 32
# Inserted batch 33
# Inserted batch 34
# Inserted batch 35
# Inserted batch 36
# Inserted batch 37
# Inserted batch 38
# Inserted batch 39
# Inserted batch 40
# Inserted batch 41
# Inserted batch 42
# Inserted batch 43
# Inserted batch 44
# Inserted batch 45
# Inserted batch 46
# Inserted batch 47
# Inserted batch 48
# Inserted batch 49
# Inserted batch 50
# ...
